# %%
from astropy.io import fits
import matplotlib.pyplot as plt
from pathlib import Path

base_path = Path("/Users/danielbhuglah/Downloads/")
base_path = Path("/Users/danielbhuglah/Library/CloudStorage/OneDrive-TheOpenUniversity/SXS841 OSO Observations/2026_02_24_files_consolidated")
file_name = "PIRATE_21160_OSL_00_zx791966_TOI_1266_c_R1_00_R105_00_2026_02_25_04_06_19.fits"

full_path = base_path/file_name

''' hdul = fits.open("/Users/danielbhuglah/Downloads/dss2-blue.13.11.59.179200+65.50.1.32000000003.fits") '''
hdul = fits.open(full_path)
plt.imshow(hdul[0].data, cmap='gray')
plt.colorbar()
