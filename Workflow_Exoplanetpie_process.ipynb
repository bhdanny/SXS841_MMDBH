# %% [markdown]
# ```mermaid
# sequenceDiagram
#  %% Define actors and participants (eg systems and databases)
#     Actor AST as Astronomer
#     participant EPP as Exoplanetpie
#
#
# %% add message numbering
#     autonumber
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EPP Step 1. Get data frpm Satellites
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EPP Step 1. Get data from Satellites
#         AST-->>EPP: Step 1.1 Enter Star name and get files from Space Telescope pipelines
#         note over AST,EPP: Choose to pdcasp_flux of sap_flux
#         AST->>EPP: Step 1.2.0 Use filters to select files for processing
#         EPP->>EPP:Step 1.2.1 For each curve run i) Eleanor - to extract usable TESS light curves <br/> ii)WOTAN - to detrend for stellar variability and instrument noise
#         note over EPP: Judgement call: WOTAN allows 18 parameters to be adjusted
#         AST->>EPP: Select light curves for download
#         note over EPP: Judgement call: Which light curves should be selected for further processing
#         AST->>EPP:Step 3 Download files for futher processing
#
#     end
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EPP Step Star and Planet: The Data
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EPP Step.Get Star and Planet Data
#          AST-->>EPP: Enter star and planet information for model fitting
#          note over AST: Judgement call: What parameters should be used
#          note over AST,EPP: Data can be entered manual or retrieved from NASA archive and ExoFOP <br/> or loaded from saved file
#          AST-->>EPP: Save data for later (or repeat) processing steps
#     end
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EPP Step 2. Prepare Data
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EPP Step 2.Prepare files to fit
#         AST-->>EPP: Step 2.1: Load Raw Files saved in EPP Step 1
#         note over AST,EPP: Can load the TESS files or a HOPS curve mocked up to replicate the TESS format.
#         AST-->>EPP: Step 2.2 Load star and planet data saved in EPP Step "Get Star and planet data"
#         note over AST,EPP: Assume transit is known to occur, so select EPOCH <br/> user period and duration when looking for a transit
#         AST-->>EPP: Set Selection window in hours that encompasses transit and ingress/egress period.
#         note over EPP: Judgement call: What size shoudl the selection window be ?
#         AST-->>EPP: Step 3 Create cycles
#         note over EPP: Judgement call: Select which cycles should be retained and saved for further processing steps.
#         AST-->>EPP: Save cycle data for later processing
#
#
#
#     end
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EPP Step 3. Fit the Transits
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EPP Step 3.Fit the transits
#         AST-->>EPP: Step 3.1: Load star and planet data saved in EPP Step "Get Star and planet data"
#         AST-->>EPP: Step 3.2: Load transit times file.
#         note over EPP: Can load EPP file or HOPS light curve
#         AST-->>EPP: Fill All using Batman module.Set fitting parameters
#         note over EPP: Judgement call: set fitting parameters e.g. <br/> orbital period, Rp/Rs, sma/Rs,i,e, periastron
#         note over EPP: Judgement call: select parameters to determine limb darkening coefficients including <br/> filter and stellar model
#         AST-->>EPP: Review fitting statistics and corner plot.
#         note over EPP: Judgement call: is the fit of sufficient quality to proceed to TTV analysis?
#
#
#
#     end
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EPP Step 4. Analyse Transit Time Variations
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EPP Step 4 Part 1.Analyse Transit Time Variations
#         AST-->>EPP: Step 4.1.1: Load star and planet data saved in EPP Step "Get Star and planet data"
#         AST-->>EPP: Step 4.1.2: Load file of transit times, launches Transit merger screen
#
#     critical EPP Step 4 Part 2: Transit merger
#         AST-->>EPP: Step 4.2.1 Load file (Left tab) of transit data from EPP Step 3 "Fit the transits"
#         AST-->>EPP: Step 4.2.2 Load file of (right tab) additional transits. <br/>e.g. load adding manual light curves and merging with TESS data
#         note over AST,EPP: Judgement call: select which cycles in include/exclude
#
#     end
#         AST-->>EPP: Step 4.1.3: Running TTV Fitting routines
#         note over AST,EPP: Judgement call: Select fitting routine <br/> i) LMFIT, Emcee,Ultranest and associated fitting parameters and <br/> ii) Fitting formula, Linear, Decay and periodic
#         AST-->>EPP: Step 4.1.4: Save results for futher analysis
#
#
#     end
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EPP Step 5. Visualiser
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EPP Step 5.Visualiser
#         AST-->>EPP: Step 5.1: Load TTV analysis results
#         AST-->>EPP: Review fitting statistics and corner plot results.
#         note over AST,EPP: Judgement call:review statistics, are they of suitable quality to infer presence of TTVs?
#         AST-->>EPP: Step 5.2: Next transits
#
#
#     end
#
# ```
