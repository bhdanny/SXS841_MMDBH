# %% [markdown]
# ```mermaid
# sequenceDiagram
#  %% Define actors and participants (eg systems and databases)
#     Actor AST as Astronomer
#     participant EF as EXOFAST
#
#
# %% add message numbering
#     autonumber
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EF Step 0. Format transit light curve for upload
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EF Step 0. Prepare file for upload
#         AST->>AST: Step 0. Format CSV file for loading to EXOFAST
#         note over AST: Format is <br/> Time (BJD),<br/> Flux (normalised around 1.0),<br/> Error
#     end
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EF Step 1. Load Transit File
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EF Step 1.Load Transit File
#         AST-->>EF: Step 1.1 Select Wavelength Band
#         note over AST,EF: Set to R (red) for these PIRATE transit observations
#         AST->>EF: Step 1.2.0 Chose transit curve file to upload
#         AST->>EF:Step 1.2.1 Upload file
#         AST->>EF: Ensure Columns are correct vs, Time, Flux and Error
#         AST-->>EF: Check upload data, review Plot Data vs. Time
#         note over AST,EF: Set Axis Labels, Axis scaling, include/exclude error bars
#
#     end
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EF Step 2. RV Veocity File Options
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EF Step 2.Load Radial Velocity (RV) Data
#      AST-->>EF:  Not documented. No RV data was <br/> located for selected targets
#
#     end
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EF Step 3. Set Period and Setting Inputs
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EF Step 3.Set Period and Settings inputs
#         AST-->>EF: Step 3.1 Set Period Parameters for Lomb-Scargle periodgram
#         note over AST,EF: Judgement call: Determine Minimum and Maximum period <br/> and number of mins for LS diagram <br/> Not used in this project
#         AST-->>EF: Step 3.2 Choose Fit Type
#         note over AST,EF: Judgement Call: chi-squared or Markov Chain Monte Carlo (MCMC)
#         AST-->>EF: Step 3.3 Set Force Circular Orbit flag
#         note over AST,EF: Judgement Call: Do you want to force a cicular orbit
#         AST-->>EF: Step 3.4 Set Fit slope to RV flag
#         note over AST,EF: Judgement Call: DO you want to set this. Not used in this project
#         AST-->>EF: Step 3.5 Set Kepler Long Cadence flag
#         note over AST,EF: Judgement Call: Do you want to set this. Not used in this project
#     end
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EF Step 4. Set Prior and Prior Width Inputs
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EF Step 4.Set Prior and Prior Width Inputs
#         AST-->>EF: Retrieve planetary parameters from <br/> NASA archive or enter manually
#         note over AST,EF: Parms include: Transit Midpoint,Rp/Rs,i,a/Rs, <br/> Baseline Flux, LDCs,Stellar surface gravity <br/>Teff, Metallicity,Orbital Period,e,Perkastron (deg),RV Amplitude,RV Slope
#         alt Retrieve from NASA archive
#             AST-->>EF: Step 4.1 Enter planet id and set which attributes to include widths
#             note over AST,EF: Judgement call: Chose all parms or Teff,Fe/H,log g or None
#         else Enter manually
#             AST-->>EF: Step 4.2 Manually enter Prior Parameters
#             note over AST,EF: Judgement Call: Which values should be used (e.g ExoClock defaults)
#         end
#         opt Save parameters
#             AST-->>EF: Step 4.3 Optional: Can save parameters and reload for later runs
#         end
#     end
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %% EF Step 5. Submit for fitting
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#     critical EF Step 5. Submit for Fitting
#         EF-->>EF: Fitting process run in background.<br/> MCMC fits can   take 15 minutes, chi-squared generally less than 1 minute
#         note over EF: MCMC runtimes prevent <br/>multiple runs being completed <br/> during this project
#         AST-->>EF: Review fitting results
#         note over AST,EF: Judgement call:<br/> Assess fitting statistics, probability distributions and correlations
#     end
# ```
